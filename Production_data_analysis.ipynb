# %% [markdown]
# <a href="https://colab.research.google.com/github/sam-pyda/DataAnalytics/blob/main/Production_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import missingno as msno

# %%
Filepath = "http://bit.ly/piopetro-data1"

# %%
df=pd.read_csv(Filepath)
df.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME  ...  BORE_WI_VOL   FLOW_KIND
# 0  07-Apr-14         15/9-F-1 C  ...          NaN  production
# 1  08-Apr-14         15/9-F-1 C  ...          NaN  production
# 2  09-Apr-14         15/9-F-1 C  ...          NaN  production
# 3  10-Apr-14         15/9-F-1 C  ...          NaN  production
# 4  11-Apr-14         15/9-F-1 C  ...          NaN  production
#
# [5 rows x 16 columns]

# %%
df['DATEPRD']=pd.to_datetime(df["DATEPRD"],format= '%d-%b-%y')
df
# Out:
#          DATEPRD NPD_WELL_BORE_NAME  ...  BORE_WI_VOL   FLOW_KIND
# 0     2014-04-07         15/9-F-1 C  ...          NaN  production
# 1     2014-04-08         15/9-F-1 C  ...          NaN  production
# 2     2014-04-09         15/9-F-1 C  ...          NaN  production
# 3     2014-04-10         15/9-F-1 C  ...          NaN  production
# 4     2014-04-11         15/9-F-1 C  ...          NaN  production
# ...          ...                ...  ...          ...         ...
# 15629 2016-09-14           15/9-F-5  ...          NaN  production
# 15630 2016-09-15           15/9-F-5  ...          NaN  production
# 15631 2016-09-16           15/9-F-5  ...          NaN  production
# 15632 2016-09-17           15/9-F-5  ...          NaN  production
# 15633 2016-09-18           15/9-F-5  ...          0.0   injection
#
# [15634 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['DATEPRD', 'NPD_WELL_BORE_NAME', 'ON_STREAM_HRS',
#        'AVG_DOWNHOLE_PRESSURE', 'AVG_DOWNHOLE_TEMPERATURE', 'AVG_DP_TUBING',
#        'AVG_ANNULUS_PRESS', 'AVG_CHOKE_SIZE_P', 'AVG_WHP_P', 'AVG_WHT_P',
#        'DP_CHOKE_SIZE', 'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL',
#        'BORE_WI_VOL', 'FLOW_KIND'],
#       dtype='object')

# %%
df['NPD_WELL_BORE_NAME'].unique()
# Out:
# array(['15/9-F-1 C', '15/9-F-11', '15/9-F-12', '15/9-F-14', '15/9-F-15 D',
#        '15/9-F-4', '15/9-F-5'], dtype=object)

# %%
Well=df[df['NPD_WELL_BORE_NAME']=='15/9-F-14']
Well
# Out:
#         DATEPRD NPD_WELL_BORE_NAME  ...  BORE_WI_VOL   FLOW_KIND
# 4967 2008-02-12          15/9-F-14  ...          NaN  production
# 4968 2008-02-13          15/9-F-14  ...          NaN  production
# 4969 2008-02-14          15/9-F-14  ...          NaN  production
# 4970 2008-02-15          15/9-F-14  ...          NaN  production
# 4971 2008-02-16          15/9-F-14  ...          NaN  production
# ...         ...                ...  ...          ...         ...
# 8018 2016-09-13          15/9-F-14  ...          NaN  production
# 8019 2016-09-14          15/9-F-14  ...          NaN  production
# 8020 2016-09-15          15/9-F-14  ...          NaN  production
# 8021 2016-09-16          15/9-F-14  ...          NaN  production
# 8022 2016-09-17          15/9-F-14  ...          NaN  production
#
# [3056 rows x 16 columns]

# %%
Well.describe()
# Out:
#        ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  ...  BORE_WAT_VOL  BORE_WI_VOL
# count    3056.000000            3050.000000  ...   3056.000000          0.0
# mean       20.541194             233.074651  ...   2330.245746          NaN
# std         7.881136              64.923765  ...   1462.922870          NaN
# min         0.000000               0.000000  ...    -59.000000          NaN
# 25%        24.000000             237.493000  ...    695.500000          NaN
# 50%        24.000000             246.776000  ...   2965.500000          NaN
# 75%        24.000000             261.971250  ...   3444.250000          NaN
# max        25.000000             334.656000  ...   5692.000000          NaN
#
# [8 rows x 13 columns]

# %%
 
plt.figure(figsize=(15,6))
plt.plot(df['DATEPRD'],df['BORE_WAT_VOL'],color='pink')
plt.plot(df['DATEPRD'],df['BORE_OIL_VOL'],color='green')
plt.title('Production Data')
plt.grid()
plt.xlabel('Date')
plt.ylabel("Q[STB]")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-bc7f898f3aef> in <module>()
#       5 plt.title('Production Data')
#       6 plt.grid()
# ----> 7 plt.xlabel('Date')
#       8 plt.ylabel("Q[STB]")
#       9 plt.show()
#
# TypeError: 'str' object is not callable

# %%
plt.hist(df['AVG_DOWNHOLE_PRESSURE'],bins=50)
plt.xlim(150,400)
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
 
variable= ['ON_STREAM_HRS','BORE_OIL_VOL','AVG_ANNULUS_PRESS']
input=df[variable]
input
sns.pairplot(input)

# %%
msno.matrix(df)

# %%
df=df.interpolate(method='linear')
msno.matrix(df)
